# %%
# !nvidia-smi

import torch
# Out:
# Thu May 22 15:56:56 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.61                 Driver Version: 572.61         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   37C    P0             21W /   40W |       0MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No CUDA device")

print()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

a = torch.rand(3, 3).to(device)
b = torch.rand(3, 3).to(device)
c = a + b

print("a + b =", c)
print("\nВычислено на:", device)
# Out:
# True
# NVIDIA GeForce RTX 3070 Laptop GPU
#
# a + b = tensor([[1.2505, 1.2904, 0.8103],
#         [0.8795, 1.0671, 0.3100],
#         [1.4741, 0.7076, 1.0108]], device='cuda:0')
#
# Вычислено на: cuda

# %%
import tensorflow as tf

tf.config.list_physical_devices('GPU')

if torch.cuda.is_available():
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("No GPU available.")

print("В итоге работает на torch")
# Out:
# Number of GPUs: 1
# GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
# В итоге работает на torch

# %% [markdown]
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118

# %%
import torch

if torch.cuda.is_available():
    print(f"✅ CUDA доступна: {torch.cuda.get_device_name(0)}")
    print(f"Количество GPU: {torch.cuda.device_count()}")
else:
    print("❌ CUDA не доступна. Используется CPU.")
# Out:
# ✅ CUDA доступна: NVIDIA GeForce RTX 3070 Laptop GPU
# Количество GPU: 1

# %%
# Создаём тензор и перемещаем его на GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

a = torch.rand(3, 3).to(device)
b = torch.rand(3, 3).to(device)
c = a + b

print("a + b =", c)
print("Вычислено на:", device)
# Out:
# a + b = tensor([[0.1690, 0.0670, 0.6777],
#         [1.0652, 0.8631, 1.6077],
#         [1.2344, 0.7954, 1.4345]], device='cuda:0')
# Вычислено на: cuda

# %% [markdown]
# На маке работает на keras на jax иначе не работает.
#
# На винде cuda работает на torch без проблем только torch устанавливаем с поддержкой cuda
#
# На винде cuda доступна и на tensorflow, но нужно будет поставить cuda на wsl вместе с tensorflow и запускать cuda с wsl иначе не работает
#
# По скорости на винде torch и tensorflow одинаковы выйдут
#
# На linux работает torch, tensorflow тоже должен в теории

# %%
from tensorflow.python.client import device_lib

def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print(get_available_devices())
# Out:
# ['/device:CPU:0']
