# %% [markdown]
# # Приступим к работе...
#
# ### Генетический алгоритм
#
# **Генетический алгоритм** (англ. genetic algorithm) - это некий эвристический алгоритм поиска, используемый для решения задач оптимизации и моделирования путём случайного подбора, комбинирования и вариации искомых параметров с использованием механизмов, аналогичных естественному отбору в природе. Используется данный алгоритм там, где не эффективно применять традиционные методы. В случае с большим пространством поиска, нелинейностью и дискретностью.
#
# ##### Постановка задачи лабораторной работы
# Пока что самое интересное применение генетического алгоритма я вижу в маршрутизации между странами или городами. После долгих раздумий было принято решение поработать с задачей оптимизации в нахождении кратчайшего маршрута (пути) между городами с помощью генетического алгоритма

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# Загружаем данные
df = pd.read_csv('.//static//GA_csv//city.csv')
print(df.columns)
# Out:
# Index(['address', 'postal_code', 'country', 'federal_district', 'region_type',
#        'region', 'area_type', 'area', 'city_type', 'city', 'settlement_type',
#        'settlement', 'kladr_id', 'fias_id', 'fias_level', 'capital_marker',
#        'okato', 'oktmo', 'tax_office', 'timezone', 'geo_lat', 'geo_lon',
#        'population', 'foundation_year'],
#       dtype='object')

# %%
print("Список городов:")
df.head()
# Out:
# Список городов:
#                     address  postal_code country federal_district region_type  \
# 0   Респ Адыгея, г Адыгейск     385200.0  Россия            Южный        Респ
# 1                  г Майкоп     385000.0  Россия            Южный        Респ
# 2           г Горно-Алтайск     649000.0  Россия        Сибирский        Респ
# 3  Алтайский край, г Алейск     658125.0  Россия        Сибирский        край
# 4                 г Барнаул     656000.0  Россия        Сибирский        край
#
#       region area_type area city_type           city  ... fias_level  \
# 0     Адыгея       NaN  NaN         г       Адыгейск  ...          4
# 1     Адыгея       NaN  NaN         г         Майкоп  ...          4
# 2      Алтай       NaN  NaN         г  Горно-Алтайск  ...          4
# 3  Алтайский       NaN  NaN         г         Алейск  ...          4
# 4  Алтайский       NaN  NaN         г        Барнаул  ...          4
#
#   capital_marker        okato        oktmo  tax_office  timezone    geo_lat  \
# 0              0  79403000000  79703000001         107     UTC+3  44.878414
# 1              2  79401000000  79701000001         105     UTC+3  44.609827
# 2              2  84401000000     84701000         400     UTC+7  51.958103
# 3              0   1403000000      1703000        2201     UTC+7  52.492251
# 4              2   1401000000      1701000        2200     UTC+7  53.347997
#
#      geo_lon  population foundation_year
# 0  39.190289       12689            1969
# 1  40.100661      144055            1857
# 2  85.960324       62861            1830
# 3  82.779361       28528            1913
# 4  83.779806      635585            1730
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#          postal_code      kladr_id   fias_level  capital_marker         okato  \
# count    1116.000000  1.117000e+03  1117.000000     1117.000000  1.117000e+03
# mean   410839.125448  4.498127e+12     3.997314        0.646374  4.743788e+10
# std    190039.321361  2.144572e+12     0.186920        0.612970  2.689631e+10
# min    101000.000000  1.000001e+11     1.000000        0.000000  1.214501e+09
# 25%    231198.250000  2.900000e+12     4.000000        0.000000  2.522851e+10
# 50%    401555.000000  4.700500e+12     4.000000        1.000000  4.644951e+10
# 75%    622270.000000  6.200600e+12     4.000000        1.000000  6.843000e+10
# max    694920.000000  9.200000e+12     6.000000        3.000000  9.940100e+10
#
#               oktmo   tax_office      geo_lat      geo_lon
# count  1.117000e+03  1117.000000  1117.000000  1117.000000
# mean   3.124660e+10  4520.452104    54.553230    54.812348
# std    3.009752e+10  2140.781941     5.226471    27.874182
# min    1.614101e+06   105.000000    42.058966    19.914057
# 25%    8.061310e+07  2904.000000    52.144962    37.861855
# 50%    2.563611e+10  4702.000000    55.150801    43.919154
# 75%    5.765710e+10  6214.000000    57.145108    60.107757
# max    9.962010e+10  9200.000000    69.701666   177.501542

# %%
print(df.isnull().sum())

print(df.isnull().any())
# Out:
# address                0
# postal_code            1
# country                0
# federal_district       0
# region_type            0
# region                 0
# area_type            505
# area                 505
# city_type              4
# city                   4
# settlement_type     1115
# settlement          1115
# kladr_id               0
# fias_id                0
# fias_level             0
# capital_marker         0
# okato                  0
# oktmo                  0
# tax_office             0
# timezone               0
# geo_lat                0
# geo_lon                0
# population             0
# foundation_year        0
# dtype: int64
# address             False
# postal_code          True
# country             False
# federal_district    False
# region_type         False
# region              False
# area_type            True
# area                 True
# city_type            True
# city                 True
# settlement_type      True
# settlement           True
# kladr_id            False
# fias_id             False
# fias_level          False
# capital_marker      False
# okato               False
# oktmo               False
# tax_office          False
# timezone            False
# geo_lat             False
# geo_lon             False
# population          False
# foundation_year     False
# dtype: bool

# %%
# Проверка типов столбцов
df.dtypes
# Out:
# address              object
# postal_code         float64
# country              object
# federal_district     object
# region_type          object
# region               object
# area_type            object
# area                 object
# city_type            object
# city                 object
# settlement_type      object
# settlement           object
# kladr_id              int64
# fias_id              object
# fias_level            int64
# capital_marker        int64
# okato                 int64
# oktmo                 int64
# tax_office            int64
# timezone             object
# geo_lat             float64
# geo_lon             float64
# population           object
# foundation_year      object
# dtype: object

# %% [markdown]
# ### Генетический алгоритм
#
# **Определение задачи оптимизации**
# *Задача:* Необходимо реализовать генетический алгоритм для решения задачи коммивояжёра (TSP) для построения маршрутов между городами по России.
#
# *Цель:* Найти кратчайший путь, по которому можно посетить все выбранные города по одному разу и вернётся в исходный город.
#
# Датасет [Сoordinates of Russian cities](https://www.kaggle.com/datasets/senatorov1/coordinates-of-russian-cities/) содержит информацию о городах России.
# #### Описание датасета и атрибутов
# 1. address - адрес населённого пункта
# 2. postal_code - почтовый индекс
# 3. federal_district - федеральный округ
# 4. region_type - тип региона
# 5. region - регион
# 6. city - город
# 7. timezone - часовой пояс
# 8. geo_lat - широта
# 9. geo_lon - долгота
# 10. population - население
# 11. foundation_year - год основания
#
# Чтобы решить задачу коммивояжёра важно учитывать:
# * Координаты городов (Широта и долгота) для расчёта расстояния
# * Название самих городов через которые будет идти путь
# * Население и год основания, чтобы посещать исторически значимые и крупные города.
#
# А также отфильтрую по округам.

# %%
# Загрузка данных
df = pd.read_csv('.//static//GA_csv//city.csv')

# Преобразуем годы основания и население в числовой тип
df["foundation_year"] = pd.to_numeric(df["foundation_year"], errors="coerce")
df["population"] = pd.to_numeric(df["population"], errors="coerce")

# Задаём нужные округа
target_districts = ["Северо-Западный", "Центральный", "Приволжский", "Южный"]

# Фильтрация по году основания, населению и федеральному округу
historic_large_cities = df[
    (df["foundation_year"] < 1800) &
    (df["population"] > 500_000) &
    (df["federal_district"].isin(target_districts))
].copy()

# Удалим дубликаты по названию города
historic_large_cities = historic_large_cities.drop_duplicates(subset=["region"])

# Сортировка по населению
historic_large_cities = historic_large_cities.sort_values("population", ascending=False)

# Сброс индекса
historic_large_cities = historic_large_cities.reset_index(drop=True)

# Вывод нужных столбцов
selected_columns = ["address", "city", "region", "country", "federal_district", "population", "foundation_year", "geo_lat", "geo_lon"]
print(f"Исторически значимые города из {target_districts} с населением более 500 000:")
display(historic_large_cities[selected_columns])
# Out:
# Исторически значимые города из ['Северо-Западный', 'Центральный', 'Приволжский', 'Южный'] с населением более 500 000:
#               address             city           region country  \
# 0            г Москва              NaN           Москва  Россия
# 1   г Санкт-Петербург              NaN  Санкт-Петербург  Россия
# 2   г Нижний Новгород  Нижний Новгород    Нижегородская  Россия
# 3            г Казань           Казань        Татарстан  Россия
# 4            г Самара           Самара        Самарская  Россия
# 5    г Ростов-на-Дону   Ростов-на-Дону       Ростовская  Россия
# 6               г Уфа              Уфа     Башкортостан  Россия
# 7         г Волгоград        Волгоград    Волгоградская  Россия
# 8             г Пермь            Пермь         Пермский  Россия
# 9           г Воронеж          Воронеж      Воронежская  Россия
# 10          г Саратов          Саратов      Саратовская  Россия
# 11        г Краснодар        Краснодар    Краснодарский  Россия
# 12           г Ижевск           Ижевск       Удмуртская  Россия
# 13        г Ульяновск        Ульяновск      Ульяновская  Россия
# 14        г Ярославль        Ярославль      Ярославская  Россия
# 15         г Оренбург         Оренбург     Оренбургская  Россия
# 16           г Рязань           Рязань        Рязанская  Россия
# 17        г Астрахань        Астрахань     Астраханская  Россия
# 18            г Пенза            Пенза       Пензенская  Россия
# 19           г Липецк           Липецк         Липецкая  Россия
# 20             г Тула             Тула         Тульская  Россия
#
#    federal_district  population  foundation_year    geo_lat    geo_lon
# 0       Центральный  11514330.0           1147.0  55.754047  37.620405
# 1   Северо-Западный   4848742.0           1703.0  59.939131  30.315900
# 2       Приволжский   1250615.0           1221.0  56.324063  44.005391
# 3       Приволжский   1216965.0           1005.0  55.794358  49.111497
# 4       Приволжский   1164900.0           1586.0  53.195031  50.106952
# 5             Южный   1091544.0           1749.0  47.222457  39.718803
# 6       Приволжский   1062300.0           1574.0  54.734944  55.957847
# 7             Южный   1021244.0           1589.0  48.707004  44.517034
# 8       Приволжский   1000679.0           1723.0  58.010258  56.234203
# 9       Центральный    889680.0           1586.0  51.659333  39.196923
# 10      Приволжский    836900.0           1590.0  51.530305  45.952935
# 11            Южный    744933.0           1793.0  45.040160  38.975965
# 12      Приволжский    628117.0           1760.0  56.852738  53.211490
# 13      Приволжский    613793.0           1648.0  54.307941  48.374849
# 14      Центральный    591486.0           1010.0  57.621548  39.897741
# 15      Приволжский    570329.0           1743.0  51.787509  55.101883
# 16      Центральный    525062.0           1095.0  54.625445  39.735861
# 17            Южный    520662.0           1558.0  46.365565  48.055924
# 18      Приволжский    519592.0           1663.0  53.175331  45.034863
# 19      Центральный    508124.0           1703.0  52.610249  39.594788
# 20      Центральный    501129.0           1146.0  54.192056  37.615384

# %% [markdown]
# ### Визуализация городов

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))

# Построение точек: население делим для масштабирования
plt.scatter(
    historic_large_cities["geo_lon"],
    historic_large_cities["geo_lat"],
    s=historic_large_cities["population"] / 100000,
    alpha=0.6,
    color='royalblue',
    edgecolors='k'
)

# Подписи городов
for _, row in historic_large_cities.iterrows():
    plt.text(
        row["geo_lon"] + 0.3,
        row["geo_lat"] + 0.3,
        f"{row['address']} ({row['region']})",
        fontsize=8,
        ha="left",
        va="center"
    )

# Подписи и оформление
plt.title("Исторически крупные города с населением > 500 000", fontsize=14)
plt.xlabel("Долгота", fontsize=12)
plt.ylabel("Широта", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import contextily as ctx
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import matplotlib.pyplot as plt

# Создаем GeoDataFrame из наших данных
geometry: list[Point] = [
    Point(lng, lat) 
    for lng, lat in zip(
        historic_large_cities["geo_lon"], 
        historic_large_cities["geo_lat"]
    )
]
geodataframe = gpd.GeoDataFrame(historic_large_cities, geometry=geometry)

# Указываем исходную систему координат (широта/долгота)
geodataframe.set_crs(epsg=4326, inplace=True)

# Преобразуем в Web Mercator для корректного отображения карты
geodataframe: GeoDataFrame = geodataframe.to_crs(epsg=3857)

# Создаем график
plt.figure(figsize=(15, 10))
ax = plt.subplot(111)

# Отображаем города
geodataframe.plot(
    ax=ax, 
    marker="o", 
    color="red", 
    markersize=geodataframe["population"] / 400000, 
    alpha=0.7
)

# Подписи городов
for x, y, label in zip(geodataframe.geometry.x, geodataframe.geometry.y, geodataframe["address"]):
    ax.annotate(
        label, xy=(x, y), xytext=(5, 5), textcoords="offset points", 
        fontsize=9, color="black", 
        bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="none", alpha=0.7)
    )

# Добавляем фон-карту
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# Оформление
ax.set_axis_off()
plt.title(f"Самые населенные города России", fontsize=15, pad=20)
plt.tight_layout()
plt.show()

# %%
import networkx as nx
from geopy.distance import geodesic
import matplotlib.pyplot as plt

# Создаём пустой граф
G = nx.Graph()

# Добавляем узлы
for _, row in historic_large_cities.iterrows():
    G.add_node(
        row["address"],
        region=row["region"],
        country=row["country"],
        population=row["population"],
        year=row["foundation_year"],
        pos=(row["geo_lon"], row["geo_lat"])  # Для визуализации
    )

# Добавляем рёбра между всеми парами городов
cities = historic_large_cities[["address", "geo_lat", "geo_lon"]].values

for i in range(len(cities)):
    for j in range(i + 1, len(cities)):
        city1, lat1, lon1 = cities[i]
        city2, lat2, lon2 = cities[j]
        distance = geodesic((lat1, lon1), (lat2, lon2)).meters
        G.add_edge(city1, city2, weight=distance)

print(f"Граф построен: {G.number_of_nodes()} узлов, {G.number_of_edges()} рёбер")
# Out:
# Граф построен: 21 узлов, 210 рёбер

# %%
# Позиции узлов
pos = nx.get_node_attributes(G, "pos")

plt.figure(figsize=(14, 10))

# Визуализация
nx.draw_networkx_nodes(G, pos, node_size=50, node_color='dodgerblue')
nx.draw_networkx_edges(G, pos, width=0.5, alpha=0.6)

# Подписи городов (можно отключить при большом количестве)
nx.draw_networkx_labels(G, pos, font_size=7)

plt.title("Граф исторически значимых крупных городов (основание до 1800 г.)", fontsize=14)
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Проектирование хромосом
#
# Для того, чтобы решить задачу генетическим алгоритмом нам нужно спроектировать хромосомы, используя кросинговер.
#
# > **Проектирование хромосом** - это один из важных и ключевых этапов разработки генетического алгоритма (ГА).
# *Хромосома* - это закодированное представление решения задачи. Она должна быть компактной, эффективной, позволять легко применять операторы кросинговера и мутации и в конечном итоге отражать возможные решения задачи или алгоритма. Иными словами Хромосома - это цепочка генов, то есть полное решение задачи. (В моей задаче - это маршрут или последовательность городов).
#
# > **Ген** – это минимальный элемент решения. В нашем случае - это город из списка городов. Каждое число есть определённый город. (п, 10 городов - список от 0 до 9).
#
# Основной особенностью является то, что в хромосоме каждый ген должен встречаться только один раз, ведь мы не можем посещать один город дважды в этой задаче.
#
# > **Фитнес-функция (Fitness Function)** — это ключевой компонент эволюционных алгоритмов (генетических алгоритмов, swarm optimization), который оценивает качество решения и определяет, насколько хорошо оно соответствует поставленной задаче. Простыми словами *фитнес-функция* — это "измеритель приспособленности" кандидата (решения) к заданным условиям. Чем выше значение фитнес-функции, тем лучше решение.
#
# *Фитнес-функция* будет оценивать, насколько хорош этот маршрут. В нашем случае – чем короче общее расстояние маршрута, тем лучше хромосома. Поэтому алгоритм будет стремиться находить хромосомы с минимальной длиной пути.

# %%
cities_list = list(G.nodes)
n = len(cities_list)
distance_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        if i != j:
            try:
                distance_matrix[i, j] = nx.shortest_path_length(
                    G, source=cities_list[i], target=cities_list[j], weight='weight'
                )
            except nx.NetworkXNoPath:
                distance_matrix[i, j] = 1e6  # Штраф

# %%
import random
import networkx as nx
from typing import List, Optional


# ===== Хромосома =====
class Chromosome:
    # ----- Инициализация решения -----
    def __init__(self, chromosome: List[int], distance_matrix: np.ndarray):
        if len(set(chromosome)) != len(chromosome):
            raise ValueError("Хромосома содержит дубликаты")
        self.chromosome = chromosome
        self.distance_matrix = distance_matrix
        self._total_distance: Optional[float] = None
        self._fitness: Optional[float] = None


    # ----- Проверка хромосомы на соответствие -----
    def valid_chromosome(self, chromosome: List[int], count_cities: int) -> bool:
        """ Проверка типа данных """
        if not isinstance(chromosome, list) or not all(isinstance(gene, int) for gene in chromosome):
            return False
            
        """ Проверка длины хромосомы """
        if len(chromosome) != count_cities:
            return False
        
        """ Проверка уникальности генов """
        if len(set(chromosome)) != count_cities:
            return False
        
        """ Проверка диапазона значений """
        if any(gene < 0 or gene >= count_cities for gene in chromosome):
            return False
            
        return True
    
    
    # ----- Вычисляем общую длину маршрута -----
    @property
    def _fitness_total_distance(self) -> float:
        if self._total_distance is None:
            self._total_distance = 0.0
            self._total_distance = sum(
                self.distance_matrix[self.chromosome[i], self.chromosome[(i + 1) % len(self.chromosome)]]
                for i in range(len(self.chromosome))
            )
        return self._total_distance
    
    
    # ----- Решаем и получаем значение fitness-функции -----
    @property
    def fitness(self) -> float:
        """Вычисляем как обратную величину к общей длине маршрута"""
        if self._fitness is None:
            self._fitness = 1 / self._fitness_total_distance
        return self._fitness
    

    # ----- Эволюция популяции -----
    @property
    def evaluate(self) -> float:
        return self.fitness
    
    
    # ----- Мутация -----
    def mutate(self):
        i, j = random.sample(range(len(self.chromosome)), 2)
        self.chromosome[i], self.chromosome[j] = self.chromosome[j], self.chromosome[i]
        self._fitness = None
        self._total_distance = None
    

    # ----- Представление решения в виде строки -----
    def __self__(self) -> str:
        return f"Маршрут: {self.chromosome} | Длина: {self._total_distance:.2f} км"

# %% [markdown]
# ### Генерация начальной популяции
#
# Создадим популяцию случайным образом, где каждая хромосома индекс города, которая каждый раз переставляется, что обеспечивает разнообразие начальных решений.

# %%
# ====== Генерация начальной популяции =====
def generate_initial_population(population_size: int, count_cities: int) -> List[List[int]]:
    """Создает начальную популяцию случайных маршрутов."""
    population = []
    for _ in range(population_size):
        chromosome = list(range(count_cities))
        random.shuffle(chromosome)
        population.append(chromosome)
    return population

# %% [markdown]
# ### Кроссинговер
#
# > **Кроссинговер** – это процесс обмена участками хромосом между родительскими особями для создания потомства. В данной задаче используется упорядоченный кроссовер (OX1), который сохраняет порядок городов из родительских маршрутов, избегая дублирований.
#
# Алгоритм работает следующим образом:
#
# Выбирается случайный отрезок из первого родителя и копируется в потомка.
# Оставшиеся города заполняются из второго родителя, начиная с конца выбранного отрезка, в порядке их появления, но исключая уже скопированные города. Этот метод позволяет комбинировать удачные участки маршрутов, сохраняя при этом допустимость решения (каждый город посещается ровно один раз).

# %%
# ===== Кроссинговер =====
def crossover(parent1: Chromosome, parent2: Chromosome) -> Chromosome:
    """Реализует упорядоченный одноточечный кроссинговер (OX1)."""
    size = len(parent1.chromosome)
    cut = random.randint(1, size - 2)
    head = parent1.chromosome[:cut]
    tail = [gene for gene in parent2.chromosome if gene not in head]
    return Chromosome(head + tail, parent1.distance_matrix)


# ===== Селекция (турнирный отбор) ======
def tournament_selection(population: List[Chromosome], tournament_size: int = 3) -> Chromosome:
    """Выбирает лучшую хромосому из случайной подгруппы."""
    contenders = random.sample(population, tournament_size)
    return max(contenders, key=lambda chrom: chrom.fitness)

# %% [markdown]
# ### Оператор мутации
#
# > **Мутация** - это оператор в эволюционных алгоритмах (например, генетических алгоритмах), который случайным образом изменяет часть решения (особи) для внесения разнообразия в популяцию и предотвращения преждевременной сходимости к субоптимальным решениям.
#
# Простыми словами это "случайное изменение" параметров решения, имитирующее биологические мутации. Она помогает алгоритму исследовать новые области пространства решений.
#
# *Мутация* вносит случайные изменения в хромосому, чтобы увеличить разнообразие популяции и избежать преждевременной сходимости к локальному оптимуму. В данном случае применяются два типа мутаций:
#
# * *Обменная мутация* (swap mutation) – случайно выбираются два гена (города) в хромосоме и меняются местами.
#
# * *Мутация перемешиванием* (scramble mutation) – случайный подотрезок хромосомы перемешивается, изменяя порядок городов внутри него.
#
# Мутация происходит с заданной вероятностью (mutation_rate), что позволяет контролировать баланс между исследованием новых решений и сохранением уже найденных хороших вариантов.

# %%
# ===== Обменная мутация =====
def swap_mutate(chromosome: List[int], mutation_rate: float) -> Chromosome:
    """Случайно меняет местами 2 города"""
    if np.random.random() < mutation_rate:
        genes = chromosome.chromosome
        idx1, idx2 = np.random.choice(len(genes), 2, replace=False)
        genes[idx1], genes[idx2] = genes[idx2], genes[idx1]
    return chromosome


# ===== Мутация перемешиванием =====
def scramble_mutation(chromosome: List[int], mutation_rate: float) -> Chromosome:
    """Мутация "перемешиванием" случайного отрезка"""
    if np.random.random() < mutation_rate:
        size: int = len(chromosome)
        start, end = sorted(np.random.randint(0, size, 2))
        segment: List[int] = chromosome[start:end]
        np.random.shuffle(segment)
        chromosome[start:end] = segment
    return chromosome

# %% [markdown]
# ### Генетический алгоритм
#
# > **Генетический алгоритм (ГА)** — это эволюционный метод оптимизации и поиска решений, основанный на принципах естественного отбора и генетики. Он используется для решения сложных задач, где традиционные методы неэффективны.
#
# *Ключевые этапы генетического алгоритма*
# 1. Инициализация популяции (Создается начальная популяция)
# * Создаётся набор случайных решений («особей»).
# * Каждая особь представляет собой закодированное решение (битовую строку, вектор чисел).
# 2. Оценка приспособленности (Fitness Function)
# * Каждая особь оценивается с помощью фитнес-функции, которая определяет её качество (коммивояжёр - длина маршрута).
# 3. Селекция (Отбор)
# * Выбираются лучшие особи для «размножения».
# * Методы: Рулетка (вероятность выбора пропорциональна fitness). Турнирный отбор (случайная выборка + выбор лучшего).
# 4. Скрещивание (Crossover)
# * Родительские особи обмениваются частями своих решений.
# Одноточечное скрещивание: Родитель1: [A,B,C,D], Родитель2: [1,2,3,4] → Потомок: [A,B,3,4]. Двухточечное: Потомок: [A,2,3,D]
# 5. Мутация
# * Случайное изменение части решения для разнообразия. Пример: [A,B,C,D] → [A,X,C,D] (мутировал 2-й ген).
# 6. Замена поколений
# * Новое поколение заменяет старое (или частично).
# * Стратегии: Полная замена (все родители умирают). Элитизм (лучшие особи сохраняются).
# 7. Критерии остановки (Алгоритм завершается при...)
# * Достижении max итераций.
# * Нахождении решения с достаточным fitness.
# * Отсутствии улучшений несколько поколений.
#
# **Основной эволюционный цикл** Для каждого поколения выполняются следующие шаги:
#
# 1. Оценка приспособленности Для каждой хромосомы вычисляется фитнес-функция как обратная величина к длине маршрута. Это делает более короткие маршруты более предпочтительными.
# 2. Отбор элиты Лучшие elite_size решений переходят в следующее поколение без изменений, сохраняя уже найденные хорошие варианты.
# 3. Формирование нового поколения Популяция дополняется потомками, созданными с помощью: Турнирного отбора (случайно выбираются несколько особей), Упорядоченного кроссовера (комбинация родительских маршрутов) и Мутаций - случайные изменения (обмен городов или перемешивание).

# %%
from typing import Callable, List

# ===== Основной цикл Генетического Алгоритма ----
def genetic_algorithm(cities: pd.DataFrame, generations: int = 400, mutation_rate: float = 0.01, population_size: int = 100,
    elite_size: int = 20, crossover_function: Callable = crossover, mutation_function: Callable = swap_mutate) -> Chromosome:
    """Запускает генетический алгоритм."""
    
    # Создание матрицы расстояний
    fitness_history = []
    coords = cities[["geo_lat", "geo_lon"]].values
    distance_matrix = np.zeros((len(coords), len(coords)))
    for i in range(len(coords)):
        for j in range(len(coords)):
            if i != j:
                distance_matrix[i][j] = haversine_distance(coords[i], coords[j])
    
    # Генерация начальной популяции как объектов Chromosome
    population: List[Chromosome] = [
        Chromosome(chromo, distance_matrix)
        for chromo in generate_initial_population(population_size, len(cities))
    ]

    # Основной цикл эволюции
    for generation in range(generations):
        # Сортировка по приспособленности
        population.sort(key=lambda x: x.fitness, reverse=True)

        # Элита
        new_population: List[Chromosome] = population[:elite_size]

        # Генерация потомков
        while len(new_population) < population_size:
            parent1 = tournament_selection(population, tournament_size=3)
            parent2 = tournament_selection(population, tournament_size=3)
            
            child = crossover_function(parent1, parent2)

            if random.random() < mutation_rate:
                mutation_function(child, mutation_rate)

            new_population.append(child)

        population = new_population
        best = population[0]
        fitness_history.append(1 / best.fitness)  # Длина маршрута в км или м
        print(f"Поколение {generation + 1} | Лучшая длина маршрута: {1 / best.fitness:.2f} км")

    return population[0], fitness_history



def haversine_distance(coordinate1: np.ndarray, coordinate2: np.ndarray) -> float:
    """Вычисляет расстояние между двумя точками на сфере (в км) по формуле гаверсинусов."""
    lat1, lon1 = coordinate1
    lat2, lon2 = coordinate2
    
    # Конвертация градусов в радианы
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Разницы координат
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # Формула гаверсинусов
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Радиус Земли в километрах
    r = 6371
    return c * r

# %%
# Запуск Генетического Алгоритма
best, fitness_history = genetic_algorithm(
    historic_large_cities,
    population_size=100,
    elite_size=20,
    mutation_rate=0.05,
    generations=500,
    crossover_function=crossover,
    mutation_function=swap_mutate
)

print(f"Лучший маршрут: {best.chromosome}")
print(f"Общая длина маршрута: {1 / best.fitness:.2f} км")
# Out:
# Поколение 1 | Лучшая длина маршрута: 13833.76 км
# Поколение 2 | Лучшая длина маршрута: 12623.30 км
# Поколение 3 | Лучшая длина маршрута: 12623.30 км
# Поколение 4 | Лучшая длина маршрута: 11723.13 км
# Поколение 5 | Лучшая длина маршрута: 11723.13 км
# Поколение 6 | Лучшая длина маршрута: 10893.42 км
# Поколение 7 | Лучшая длина маршрута: 10893.42 км
# Поколение 8 | Лучшая длина маршрута: 10893.42 км
# Поколение 9 | Лучшая длина маршрута: 10893.42 км
# Поколение 10 | Лучшая длина маршрута: 10596.44 км
# Поколение 11 | Лучшая длина маршрута: 10596.44 км
# Поколение 12 | Лучшая длина маршрута: 10596.44 км
# Поколение 13 | Лучшая длина маршрута: 10596.44 км
# Поколение 14 | Лучшая длина маршрута: 10596.44 км
# Поколение 15 | Лучшая длина маршрута: 10476.68 км
# Поколение 16 | Лучшая длина маршрута: 9980.03 км
# Поколение 17 | Лучшая длина маршрута: 9980.03 км
# Поколение 18 | Лучшая длина маршрута: 9980.03 км
# Поколение 19 | Лучшая длина маршрута: 9980.03 км
# Поколение 20 | Лучшая длина маршрута: 9980.03 км
# Поколение 21 | Лучшая длина маршрута: 9980.03 км
# Поколение 22 | Лучшая длина маршрута: 9980.03 км
# Поколение 23 | Лучшая длина маршрута: 9980.03 км
# Поколение 24 | Лучшая длина маршрута: 9980.03 км
# Поколение 25 | Лучшая длина маршрута: 9980.03 км
# Поколение 26 | Лучшая длина маршрута: 9980.03 км
# Поколение 27 | Лучшая длина маршрута: 9980.03 км
# Поколение 28 | Лучшая длина маршрута: 9980.03 км
# Поколение 29 | Лучшая длина маршрута: 9980.03 км
# Поколение 30 | Лучшая длина маршрута: 9980.03 км
# Поколение 31 | Лучшая длина маршрута: 9980.03 км
# Поколение 32 | Лучшая длина маршрута: 9980.03 км
# Поколение 33 | Лучшая длина маршрута: 9980.03 км
# Поколение 34 | Лучшая длина маршрута: 9980.03 км
# Поколение 35 | Лучшая длина маршрута: 9980.03 км
# Поколение 36 | Лучшая длина маршрута: 9980.03 км
# Поколение 37 | Лучшая длина маршрута: 9980.03 км
# Поколение 38 | Лучшая длина маршрута: 9980.03 км
# Поколение 39 | Лучшая длина маршрута: 9980.03 км
# Поколение 40 | Лучшая длина маршрута: 9980.03 км
# Поколение 41 | Лучшая длина маршрута: 9980.03 км
# Поколение 42 | Лучшая длина маршрута: 9980.03 км
# Поколение 43 | Лучшая длина маршрута: 9980.03 км
# Поколение 44 | Лучшая длина маршрута: 9980.03 км
# Поколение 45 | Лучшая длина маршрута: 9980.03 км
# Поколение 46 | Лучшая длина маршрута: 9980.03 км
# Поколение 47 | Лучшая длина маршрута: 9980.03 км
# Поколение 48 | Лучшая длина маршрута: 9980.03 км
# Поколение 49 | Лучшая длина маршрута: 9980.03 км
# Поколение 50 | Лучшая длина маршрута: 9980.03 км
# Поколение 51 | Лучшая длина маршрута: 9980.03 км
# Поколение 52 | Лучшая длина маршрута: 9980.03 км
# Поколение 53 | Лучшая длина маршрута: 9980.03 км
# Поколение 54 | Лучшая длина маршрута: 9980.03 км
# Поколение 55 | Лучшая длина маршрута: 9980.03 км
# Поколение 56 | Лучшая длина маршрута: 9980.03 км
# Поколение 57 | Лучшая длина маршрута: 9980.03 км
# Поколение 58 | Лучшая длина маршрута: 9980.03 км
# Поколение 59 | Лучшая длина маршрута: 9980.03 км
# Поколение 60 | Лучшая длина маршрута: 9980.03 км
# Поколение 61 | Лучшая длина маршрута: 9980.03 км
# Поколение 62 | Лучшая длина маршрута: 9980.03 км
# Поколение 63 | Лучшая длина маршрута: 9980.03 км
# Поколение 64 | Лучшая длина маршрута: 9980.03 км
# Поколение 65 | Лучшая длина маршрута: 9980.03 км
# Поколение 66 | Лучшая длина маршрута: 9980.03 км
# Поколение 67 | Лучшая длина маршрута: 9980.03 км
# Поколение 68 | Лучшая длина маршрута: 9980.03 км
# Поколение 69 | Лучшая длина маршрута: 9980.03 км
# Поколение 70 | Лучшая длина маршрута: 9980.03 км
# Поколение 71 | Лучшая длина маршрута: 9980.03 км
# Поколение 72 | Лучшая длина маршрута: 9980.03 км
# Поколение 73 | Лучшая длина маршрута: 9980.03 км
# Поколение 74 | Лучшая длина маршрута: 9980.03 км
# Поколение 75 | Лучшая длина маршрута: 9980.03 км
# Поколение 76 | Лучшая длина маршрута: 9980.03 км
# Поколение 77 | Лучшая длина маршрута: 9980.03 км
# Поколение 78 | Лучшая длина маршрута: 9980.03 км
# Поколение 79 | Лучшая длина маршрута: 9980.03 км
# Поколение 80 | Лучшая длина маршрута: 9980.03 км
# Поколение 81 | Лучшая длина маршрута: 9980.03 км
# Поколение 82 | Лучшая длина маршрута: 9980.03 км
# Поколение 83 | Лучшая длина маршрута: 9980.03 км
# Поколение 84 | Лучшая длина маршрута: 9980.03 км
# Поколение 85 | Лучшая длина маршрута: 9976.54 км
# Поколение 86 | Лучшая длина маршрута: 9976.54 км
# Поколение 87 | Лучшая длина маршрута: 9976.54 км
# Поколение 88 | Лучшая длина маршрута: 9976.54 км
# Поколение 89 | Лучшая длина маршрута: 9976.54 км
# Поколение 90 | Лучшая длина маршрута: 9976.54 км
# Поколение 91 | Лучшая длина маршрута: 9976.54 км
# Поколение 92 | Лучшая длина маршрута: 9976.54 км
# Поколение 93 | Лучшая длина маршрута: 9976.54 км
# Поколение 94 | Лучшая длина маршрута: 9976.54 км
# Поколение 95 | Лучшая длина маршрута: 9976.54 км
# Поколение 96 | Лучшая длина маршрута: 9976.54 км
# Поколение 97 | Лучшая длина маршрута: 9976.54 км
# Поколение 98 | Лучшая длина маршрута: 9976.54 км
# Поколение 99 | Лучшая длина маршрута: 9976.54 км
# Поколение 100 | Лучшая длина маршрута: 9976.54 км
# Поколение 101 | Лучшая длина маршрута: 9976.54 км
# Поколение 102 | Лучшая длина маршрута: 9976.54 км
# Поколение 103 | Лучшая длина маршрута: 9976.54 км
# Поколение 104 | Лучшая длина маршрута: 9976.54 км
# Поколение 105 | Лучшая длина маршрута: 9976.54 км
# Поколение 106 | Лучшая длина маршрута: 9976.54 км
# Поколение 107 | Лучшая длина маршрута: 9976.54 км
# Поколение 108 | Лучшая длина маршрута: 9976.54 км
# Поколение 109 | Лучшая длина маршрута: 9976.54 км
# Поколение 110 | Лучшая длина маршрута: 9976.54 км
# Поколение 111 | Лучшая длина маршрута: 9976.54 км
# Поколение 112 | Лучшая длина маршрута: 9976.54 км
# Поколение 113 | Лучшая длина маршрута: 9976.54 км
# Поколение 114 | Лучшая длина маршрута: 9976.54 км
# Поколение 115 | Лучшая длина маршрута: 9976.54 км
# Поколение 116 | Лучшая длина маршрута: 9976.54 км
# Поколение 117 | Лучшая длина маршрута: 9976.54 км
# Поколение 118 | Лучшая длина маршрута: 9976.54 км
# Поколение 119 | Лучшая длина маршрута: 9976.54 км
# Поколение 120 | Лучшая длина маршрута: 9976.54 км
# Поколение 121 | Лучшая длина маршрута: 9976.54 км
# Поколение 122 | Лучшая длина маршрута: 9976.54 км
# Поколение 123 | Лучшая длина маршрута: 9976.54 км
# Поколение 124 | Лучшая длина маршрута: 9976.54 км
# Поколение 125 | Лучшая длина маршрута: 9976.54 км
# Поколение 126 | Лучшая длина маршрута: 9573.66 км
# Поколение 127 | Лучшая длина маршрута: 9573.66 км
# Поколение 128 | Лучшая длина маршрута: 9480.18 км
# Поколение 129 | Лучшая длина маршрута: 9480.18 км
# Поколение 130 | Лучшая длина маршрута: 9480.18 км
# Поколение 131 | Лучшая длина маршрута: 9480.18 км
# Поколение 132 | Лучшая длина маршрута: 9480.18 км
# Поколение 133 | Лучшая длина маршрута: 9480.18 км
# Поколение 134 | Лучшая длина маршрута: 9480.18 км
# Поколение 135 | Лучшая длина маршрута: 9480.18 км
# Поколение 136 | Лучшая длина маршрута: 9480.18 км
# Поколение 137 | Лучшая длина маршрута: 9480.18 км
# Поколение 138 | Лучшая длина маршрута: 9480.18 км
# Поколение 139 | Лучшая длина маршрута: 9480.18 км
# Поколение 140 | Лучшая длина маршрута: 9480.18 км
# Поколение 141 | Лучшая длина маршрута: 9480.18 км
# Поколение 142 | Лучшая длина маршрута: 9480.18 км
# Поколение 143 | Лучшая длина маршрута: 9480.18 км
# Поколение 144 | Лучшая длина маршрута: 9480.18 км
# Поколение 145 | Лучшая длина маршрута: 9480.18 км
# Поколение 146 | Лучшая длина маршрута: 9480.18 км
# Поколение 147 | Лучшая длина маршрута: 9480.18 км
# Поколение 148 | Лучшая длина маршрута: 9480.18 км
# Поколение 149 | Лучшая длина маршрута: 9480.18 км
# Поколение 150 | Лучшая длина маршрута: 9480.18 км
# Поколение 151 | Лучшая длина маршрута: 9480.18 км
# Поколение 152 | Лучшая длина маршрута: 9480.18 км
# Поколение 153 | Лучшая длина маршрута: 9480.18 км
# Поколение 154 | Лучшая длина маршрута: 9480.18 км
# Поколение 155 | Лучшая длина маршрута: 9480.18 км
# Поколение 156 | Лучшая длина маршрута: 9480.18 км
# Поколение 157 | Лучшая длина маршрута: 9480.18 км
# Поколение 158 | Лучшая длина маршрута: 9480.18 км
# Поколение 159 | Лучшая длина маршрута: 9480.18 км
# Поколение 160 | Лучшая длина маршрута: 9480.18 км
# Поколение 161 | Лучшая длина маршрута: 9480.18 км
# Поколение 162 | Лучшая длина маршрута: 9480.18 км
# Поколение 163 | Лучшая длина маршрута: 9480.18 км
# Поколение 164 | Лучшая длина маршрута: 9480.18 км
# Поколение 165 | Лучшая длина маршрута: 9480.18 км
# Поколение 166 | Лучшая длина маршрута: 9480.18 км
# Поколение 167 | Лучшая длина маршрута: 9480.18 км
# Поколение 168 | Лучшая длина маршрута: 9480.18 км
# Поколение 169 | Лучшая длина маршрута: 9480.18 км
# Поколение 170 | Лучшая длина маршрута: 9480.18 км
# Поколение 171 | Лучшая длина маршрута: 9480.18 км
# Поколение 172 | Лучшая длина маршрута: 9480.18 км
# Поколение 173 | Лучшая длина маршрута: 9480.18 км
# Поколение 174 | Лучшая длина маршрута: 9480.18 км
# Поколение 175 | Лучшая длина маршрута: 9480.18 км
# Поколение 176 | Лучшая длина маршрута: 9480.18 км
# Поколение 177 | Лучшая длина маршрута: 9480.18 км
# Поколение 178 | Лучшая длина маршрута: 9480.18 км
# Поколение 179 | Лучшая длина маршрута: 9480.18 км
# Поколение 180 | Лучшая длина маршрута: 9480.18 км
# Поколение 181 | Лучшая длина маршрута: 9480.18 км
# Поколение 182 | Лучшая длина маршрута: 9480.18 км
# Поколение 183 | Лучшая длина маршрута: 9480.18 км
# Поколение 184 | Лучшая длина маршрута: 9480.18 км
# Поколение 185 | Лучшая длина маршрута: 9480.18 км
# Поколение 186 | Лучшая длина маршрута: 9480.18 км
# Поколение 187 | Лучшая длина маршрута: 9480.18 км
# Поколение 188 | Лучшая длина маршрута: 9480.18 км
# Поколение 189 | Лучшая длина маршрута: 9480.18 км
# Поколение 190 | Лучшая длина маршрута: 9480.18 км
# Поколение 191 | Лучшая длина маршрута: 9480.18 км
# Поколение 192 | Лучшая длина маршрута: 9480.18 км
# Поколение 193 | Лучшая длина маршрута: 9480.18 км
# Поколение 194 | Лучшая длина маршрута: 9480.18 км
# Поколение 195 | Лучшая длина маршрута: 9480.18 км
# Поколение 196 | Лучшая длина маршрута: 9480.18 км
# Поколение 197 | Лучшая длина маршрута: 9480.18 км
# Поколение 198 | Лучшая длина маршрута: 9480.18 км
# Поколение 199 | Лучшая длина маршрута: 9480.18 км
# Поколение 200 | Лучшая длина маршрута: 9480.18 км
# Поколение 201 | Лучшая длина маршрута: 9480.18 км
# Поколение 202 | Лучшая длина маршрута: 9480.18 км
# Поколение 203 | Лучшая длина маршрута: 9480.18 км
# Поколение 204 | Лучшая длина маршрута: 9480.18 км
# Поколение 205 | Лучшая длина маршрута: 9480.18 км
# Поколение 206 | Лучшая длина маршрута: 9480.18 км
# Поколение 207 | Лучшая длина маршрута: 9480.18 км
# Поколение 208 | Лучшая длина маршрута: 9480.18 км
# Поколение 209 | Лучшая длина маршрута: 9480.18 км
# Поколение 210 | Лучшая длина маршрута: 9480.18 км
# Поколение 211 | Лучшая длина маршрута: 9480.18 км
# Поколение 212 | Лучшая длина маршрута: 9480.18 км
# Поколение 213 | Лучшая длина маршрута: 9480.18 км
# Поколение 214 | Лучшая длина маршрута: 9480.18 км
# Поколение 215 | Лучшая длина маршрута: 9480.18 км
# Поколение 216 | Лучшая длина маршрута: 9480.18 км
# Поколение 217 | Лучшая длина маршрута: 9480.18 км
# Поколение 218 | Лучшая длина маршрута: 9480.18 км
# Поколение 219 | Лучшая длина маршрута: 9480.18 км
# Поколение 220 | Лучшая длина маршрута: 9480.18 км
# Поколение 221 | Лучшая длина маршрута: 9480.18 км
# Поколение 222 | Лучшая длина маршрута: 9480.18 км
# Поколение 223 | Лучшая длина маршрута: 9480.18 км
# Поколение 224 | Лучшая длина маршрута: 9480.18 км
# Поколение 225 | Лучшая длина маршрута: 9480.18 км
# Поколение 226 | Лучшая длина маршрута: 9480.18 км
# Поколение 227 | Лучшая длина маршрута: 9480.18 км
# Поколение 228 | Лучшая длина маршрута: 9480.18 км
# Поколение 229 | Лучшая длина маршрута: 9480.18 км
# Поколение 230 | Лучшая длина маршрута: 9480.18 км
# Поколение 231 | Лучшая длина маршрута: 9480.18 км
# Поколение 232 | Лучшая длина маршрута: 9480.18 км
# Поколение 233 | Лучшая длина маршрута: 9480.18 км
# Поколение 234 | Лучшая длина маршрута: 9480.18 км
# Поколение 235 | Лучшая длина маршрута: 9480.18 км
# Поколение 236 | Лучшая длина маршрута: 9480.18 км
# Поколение 237 | Лучшая длина маршрута: 9480.18 км
# Поколение 238 | Лучшая длина маршрута: 9480.18 км
# Поколение 239 | Лучшая длина маршрута: 9480.18 км
# Поколение 240 | Лучшая длина маршрута: 9480.18 км
# Поколение 241 | Лучшая длина маршрута: 9480.18 км
# Поколение 242 | Лучшая длина маршрута: 9480.18 км
# Поколение 243 | Лучшая длина маршрута: 9480.18 км
# Поколение 244 | Лучшая длина маршрута: 9480.18 км
# Поколение 245 | Лучшая длина маршрута: 9480.18 км
# Поколение 246 | Лучшая длина маршрута: 9480.18 км
# Поколение 247 | Лучшая длина маршрута: 9480.18 км
# Поколение 248 | Лучшая длина маршрута: 9480.18 км
# Поколение 249 | Лучшая длина маршрута: 9480.18 км
# Поколение 250 | Лучшая длина маршрута: 9480.18 км
# Поколение 251 | Лучшая длина маршрута: 9480.18 км
# Поколение 252 | Лучшая длина маршрута: 9480.18 км
# Поколение 253 | Лучшая длина маршрута: 9480.18 км
# Поколение 254 | Лучшая длина маршрута: 9480.18 км
# Поколение 255 | Лучшая длина маршрута: 9480.18 км
# Поколение 256 | Лучшая длина маршрута: 9480.18 км
# Поколение 257 | Лучшая длина маршрута: 9480.18 км
# Поколение 258 | Лучшая длина маршрута: 9480.18 км
# Поколение 259 | Лучшая длина маршрута: 9480.18 км
# Поколение 260 | Лучшая длина маршрута: 9480.18 км
# Поколение 261 | Лучшая длина маршрута: 9480.18 км
# Поколение 262 | Лучшая длина маршрута: 9480.18 км
# Поколение 263 | Лучшая длина маршрута: 9480.18 км
# Поколение 264 | Лучшая длина маршрута: 9480.18 км
# Поколение 265 | Лучшая длина маршрута: 9480.18 км
# Поколение 266 | Лучшая длина маршрута: 9480.18 км
# Поколение 267 | Лучшая длина маршрута: 9480.18 км
# Поколение 268 | Лучшая длина маршрута: 9480.18 км
# Поколение 269 | Лучшая длина маршрута: 9480.18 км
# Поколение 270 | Лучшая длина маршрута: 9480.18 км
# Поколение 271 | Лучшая длина маршрута: 9480.18 км
# Поколение 272 | Лучшая длина маршрута: 9480.18 км
# Поколение 273 | Лучшая длина маршрута: 9480.18 км
# Поколение 274 | Лучшая длина маршрута: 9480.18 км
# Поколение 275 | Лучшая длина маршрута: 9480.18 км
# Поколение 276 | Лучшая длина маршрута: 9480.18 км
# Поколение 277 | Лучшая длина маршрута: 9480.18 км
# Поколение 278 | Лучшая длина маршрута: 9480.18 км
# Поколение 279 | Лучшая длина маршрута: 9480.18 км
# Поколение 280 | Лучшая длина маршрута: 9393.10 км
# Поколение 281 | Лучшая длина маршрута: 9177.81 км
# Поколение 282 | Лучшая длина маршрута: 9167.77 км
# Поколение 283 | Лучшая длина маршрута: 9167.77 км
# Поколение 284 | Лучшая длина маршрута: 9167.77 км
# Поколение 285 | Лучшая длина маршрута: 9167.77 км
# Поколение 286 | Лучшая длина маршрута: 9167.77 км
# Поколение 287 | Лучшая длина маршрута: 9167.77 км
# Поколение 288 | Лучшая длина маршрута: 9167.77 км
# Поколение 289 | Лучшая длина маршрута: 9167.77 км
# Поколение 290 | Лучшая длина маршрута: 9167.77 км
# Поколение 291 | Лучшая длина маршрута: 9167.77 км
# Поколение 292 | Лучшая длина маршрута: 9167.77 км
# Поколение 293 | Лучшая длина маршрута: 9167.77 км
# Поколение 294 | Лучшая длина маршрута: 9167.77 км
# Поколение 295 | Лучшая длина маршрута: 9167.77 км
# Поколение 296 | Лучшая длина маршрута: 9167.77 км
# Поколение 297 | Лучшая длина маршрута: 9167.77 км
# Поколение 298 | Лучшая длина маршрута: 9167.77 км
# Поколение 299 | Лучшая длина маршрута: 9167.77 км
# Поколение 300 | Лучшая длина маршрута: 9167.77 км
# Поколение 301 | Лучшая длина маршрута: 9167.77 км
# Поколение 302 | Лучшая длина маршрута: 9167.77 км
# Поколение 303 | Лучшая длина маршрута: 9167.77 км
# Поколение 304 | Лучшая длина маршрута: 9167.77 км
# Поколение 305 | Лучшая длина маршрута: 9167.77 км
# Поколение 306 | Лучшая длина маршрута: 9167.77 км
# Поколение 307 | Лучшая длина маршрута: 9167.77 км
# Поколение 308 | Лучшая длина маршрута: 9167.77 км
# Поколение 309 | Лучшая длина маршрута: 9167.77 км
# Поколение 310 | Лучшая длина маршрута: 9167.77 км
# Поколение 311 | Лучшая длина маршрута: 9167.77 км
# Поколение 312 | Лучшая длина маршрута: 9167.77 км
# Поколение 313 | Лучшая длина маршрута: 9167.77 км
# Поколение 314 | Лучшая длина маршрута: 9167.77 км
# Поколение 315 | Лучшая длина маршрута: 9167.77 км
# Поколение 316 | Лучшая длина маршрута: 9167.77 км
# Поколение 317 | Лучшая длина маршрута: 9167.77 км
# Поколение 318 | Лучшая длина маршрута: 9167.77 км
# Поколение 319 | Лучшая длина маршрута: 9167.77 км
# Поколение 320 | Лучшая длина маршрута: 9167.77 км
# Поколение 321 | Лучшая длина маршрута: 9167.77 км
# Поколение 322 | Лучшая длина маршрута: 9167.77 км
# Поколение 323 | Лучшая длина маршрута: 9167.77 км
# Поколение 324 | Лучшая длина маршрута: 9167.77 км
# Поколение 325 | Лучшая длина маршрута: 9167.77 км
# Поколение 326 | Лучшая длина маршрута: 9167.77 км
# Поколение 327 | Лучшая длина маршрута: 9167.77 км
# Поколение 328 | Лучшая длина маршрута: 9167.77 км
# Поколение 329 | Лучшая длина маршрута: 9167.77 км
# Поколение 330 | Лучшая длина маршрута: 9167.77 км
# Поколение 331 | Лучшая длина маршрута: 9167.77 км
# Поколение 332 | Лучшая длина маршрута: 9167.77 км
# Поколение 333 | Лучшая длина маршрута: 9167.77 км
# Поколение 334 | Лучшая длина маршрута: 9167.77 км
# Поколение 335 | Лучшая длина маршрута: 9167.77 км
# Поколение 336 | Лучшая длина маршрута: 8744.09 км
# Поколение 337 | Лучшая длина маршрута: 8744.09 км
# Поколение 338 | Лучшая длина маршрута: 8744.09 км
# Поколение 339 | Лучшая длина маршрута: 8744.09 км
# Поколение 340 | Лучшая длина маршрута: 8744.09 км
# Поколение 341 | Лучшая длина маршрута: 8744.09 км
# Поколение 342 | Лучшая длина маршрута: 8744.09 км
# Поколение 343 | Лучшая длина маршрута: 8744.09 км
# Поколение 344 | Лучшая длина маршрута: 8744.09 км
# Поколение 345 | Лучшая длина маршрута: 8744.09 км
# Поколение 346 | Лучшая длина маршрута: 8744.09 км
# Поколение 347 | Лучшая длина маршрута: 8744.09 км
# Поколение 348 | Лучшая длина маршрута: 8744.09 км
# Поколение 349 | Лучшая длина маршрута: 8744.09 км
# Поколение 350 | Лучшая длина маршрута: 8744.09 км
# Поколение 351 | Лучшая длина маршрута: 8744.09 км
# Поколение 352 | Лучшая длина маршрута: 8744.09 км
# Поколение 353 | Лучшая длина маршрута: 8744.09 км
# Поколение 354 | Лучшая длина маршрута: 8744.09 км
# Поколение 355 | Лучшая длина маршрута: 8744.09 км
# Поколение 356 | Лучшая длина маршрута: 8744.09 км
# Поколение 357 | Лучшая длина маршрута: 8744.09 км
# Поколение 358 | Лучшая длина маршрута: 8744.09 км
# Поколение 359 | Лучшая длина маршрута: 8744.09 км
# Поколение 360 | Лучшая длина маршрута: 8744.09 км
# Поколение 361 | Лучшая длина маршрута: 8744.09 км
# Поколение 362 | Лучшая длина маршрута: 8744.09 км
# Поколение 363 | Лучшая длина маршрута: 8744.09 км
# Поколение 364 | Лучшая длина маршрута: 8744.09 км
# Поколение 365 | Лучшая длина маршрута: 8744.09 км
# Поколение 366 | Лучшая длина маршрута: 8744.09 км
# Поколение 367 | Лучшая длина маршрута: 8744.09 км
# Поколение 368 | Лучшая длина маршрута: 8744.09 км
# Поколение 369 | Лучшая длина маршрута: 8744.09 км
# Поколение 370 | Лучшая длина маршрута: 8744.09 км
# Поколение 371 | Лучшая длина маршрута: 8744.09 км
# Поколение 372 | Лучшая длина маршрута: 8744.09 км
# Поколение 373 | Лучшая длина маршрута: 8744.09 км
# Поколение 374 | Лучшая длина маршрута: 8744.09 км
# Поколение 375 | Лучшая длина маршрута: 8744.09 км
# Поколение 376 | Лучшая длина маршрута: 8744.09 км
# Поколение 377 | Лучшая длина маршрута: 8744.09 км
# Поколение 378 | Лучшая длина маршрута: 8744.09 км
# Поколение 379 | Лучшая длина маршрута: 8744.09 км
# Поколение 380 | Лучшая длина маршрута: 8744.09 км
# Поколение 381 | Лучшая длина маршрута: 8744.09 км
# Поколение 382 | Лучшая длина маршрута: 8744.09 км
# Поколение 383 | Лучшая длина маршрута: 8744.09 км
# Поколение 384 | Лучшая длина маршрута: 8744.09 км
# Поколение 385 | Лучшая длина маршрута: 8744.09 км
# Поколение 386 | Лучшая длина маршрута: 8744.09 км
# Поколение 387 | Лучшая длина маршрута: 8744.09 км
# Поколение 388 | Лучшая длина маршрута: 8744.09 км
# Поколение 389 | Лучшая длина маршрута: 8744.09 км
# Поколение 390 | Лучшая длина маршрута: 8744.09 км
# Поколение 391 | Лучшая длина маршрута: 8744.09 км
# Поколение 392 | Лучшая длина маршрута: 8744.09 км
# Поколение 393 | Лучшая длина маршрута: 8744.09 км
# Поколение 394 | Лучшая длина маршрута: 8744.09 км
# Поколение 395 | Лучшая длина маршрута: 8744.09 км
# Поколение 396 | Лучшая длина маршрута: 8744.09 км
# Поколение 397 | Лучшая длина маршрута: 8744.09 км
# Поколение 398 | Лучшая длина маршрута: 8744.09 км
# Поколение 399 | Лучшая длина маршрута: 8744.09 км
# Поколение 400 | Лучшая длина маршрута: 8744.09 км
# Поколение 401 | Лучшая длина маршрута: 8744.09 км
# Поколение 402 | Лучшая длина маршрута: 8744.09 км
# Поколение 403 | Лучшая длина маршрута: 8744.09 км
# Поколение 404 | Лучшая длина маршрута: 8744.09 км
# Поколение 405 | Лучшая длина маршрута: 8744.09 км
# Поколение 406 | Лучшая длина маршрута: 8744.09 км
# Поколение 407 | Лучшая длина маршрута: 8744.09 км
# Поколение 408 | Лучшая длина маршрута: 8744.09 км
# Поколение 409 | Лучшая длина маршрута: 8744.09 км
# Поколение 410 | Лучшая длина маршрута: 8744.09 км
# Поколение 411 | Лучшая длина маршрута: 8744.09 км
# Поколение 412 | Лучшая длина маршрута: 8744.09 км
# Поколение 413 | Лучшая длина маршрута: 8744.09 км
# Поколение 414 | Лучшая длина маршрута: 8744.09 км
# Поколение 415 | Лучшая длина маршрута: 8744.09 км
# Поколение 416 | Лучшая длина маршрута: 8744.09 км
# Поколение 417 | Лучшая длина маршрута: 8744.09 км
# Поколение 418 | Лучшая длина маршрута: 8744.09 км
# Поколение 419 | Лучшая длина маршрута: 8744.09 км
# Поколение 420 | Лучшая длина маршрута: 8744.09 км
# Поколение 421 | Лучшая длина маршрута: 8744.09 км
# Поколение 422 | Лучшая длина маршрута: 8744.09 км
# Поколение 423 | Лучшая длина маршрута: 8744.09 км
# Поколение 424 | Лучшая длина маршрута: 8744.09 км
# Поколение 425 | Лучшая длина маршрута: 8744.09 км
# Поколение 426 | Лучшая длина маршрута: 8744.09 км
# Поколение 427 | Лучшая длина маршрута: 8744.09 км
# Поколение 428 | Лучшая длина маршрута: 8744.09 км
# Поколение 429 | Лучшая длина маршрута: 8744.09 км
# Поколение 430 | Лучшая длина маршрута: 8744.09 км
# Поколение 431 | Лучшая длина маршрута: 8744.09 км
# Поколение 432 | Лучшая длина маршрута: 8744.09 км
# Поколение 433 | Лучшая длина маршрута: 8744.09 км
# Поколение 434 | Лучшая длина маршрута: 8744.09 км
# Поколение 435 | Лучшая длина маршрута: 8744.09 км
# Поколение 436 | Лучшая длина маршрута: 8744.09 км
# Поколение 437 | Лучшая длина маршрута: 8744.09 км
# Поколение 438 | Лучшая длина маршрута: 8744.09 км
# Поколение 439 | Лучшая длина маршрута: 8744.09 км
# Поколение 440 | Лучшая длина маршрута: 8744.09 км
# Поколение 441 | Лучшая длина маршрута: 8744.09 км
# Поколение 442 | Лучшая длина маршрута: 8744.09 км
# Поколение 443 | Лучшая длина маршрута: 8744.09 км
# Поколение 444 | Лучшая длина маршрута: 8744.09 км
# Поколение 445 | Лучшая длина маршрута: 8744.09 км
# Поколение 446 | Лучшая длина маршрута: 8744.09 км
# Поколение 447 | Лучшая длина маршрута: 8744.09 км
# Поколение 448 | Лучшая длина маршрута: 8744.09 км
# Поколение 449 | Лучшая длина маршрута: 8744.09 км
# Поколение 450 | Лучшая длина маршрута: 8744.09 км
# Поколение 451 | Лучшая длина маршрута: 8744.09 км
# Поколение 452 | Лучшая длина маршрута: 8744.09 км
# Поколение 453 | Лучшая длина маршрута: 8744.09 км
# Поколение 454 | Лучшая длина маршрута: 8744.09 км
# Поколение 455 | Лучшая длина маршрута: 8744.09 км
# Поколение 456 | Лучшая длина маршрута: 8744.09 км
# Поколение 457 | Лучшая длина маршрута: 8744.09 км
# Поколение 458 | Лучшая длина маршрута: 8744.09 км
# Поколение 459 | Лучшая длина маршрута: 8744.09 км
# Поколение 460 | Лучшая длина маршрута: 8744.09 км
# Поколение 461 | Лучшая длина маршрута: 8744.09 км
# Поколение 462 | Лучшая длина маршрута: 8744.09 км
# Поколение 463 | Лучшая длина маршрута: 8744.09 км
# Поколение 464 | Лучшая длина маршрута: 8744.09 км
# Поколение 465 | Лучшая длина маршрута: 8744.09 км
# Поколение 466 | Лучшая длина маршрута: 8744.09 км
# Поколение 467 | Лучшая длина маршрута: 8744.09 км
# Поколение 468 | Лучшая длина маршрута: 8744.09 км
# Поколение 469 | Лучшая длина маршрута: 8744.09 км
# Поколение 470 | Лучшая длина маршрута: 8744.09 км
# Поколение 471 | Лучшая длина маршрута: 8744.09 км
# Поколение 472 | Лучшая длина маршрута: 8744.09 км
# Поколение 473 | Лучшая длина маршрута: 8744.09 км
# Поколение 474 | Лучшая длина маршрута: 8744.09 км
# Поколение 475 | Лучшая длина маршрута: 8744.09 км
# Поколение 476 | Лучшая длина маршрута: 8744.09 км
# Поколение 477 | Лучшая длина маршрута: 8744.09 км
# Поколение 478 | Лучшая длина маршрута: 8744.09 км
# Поколение 479 | Лучшая длина маршрута: 8744.09 км
# Поколение 480 | Лучшая длина маршрута: 8744.09 км
# Поколение 481 | Лучшая длина маршрута: 8744.09 км
# Поколение 482 | Лучшая длина маршрута: 8744.09 км
# Поколение 483 | Лучшая длина маршрута: 8744.09 км
# Поколение 484 | Лучшая длина маршрута: 8744.09 км
# Поколение 485 | Лучшая длина маршрута: 8744.09 км
# Поколение 486 | Лучшая длина маршрута: 8744.09 км
# Поколение 487 | Лучшая длина маршрута: 8744.09 км
# Поколение 488 | Лучшая длина маршрута: 8744.09 км
# Поколение 489 | Лучшая длина маршрута: 8744.09 км
# Поколение 490 | Лучшая длина маршрута: 8744.09 км
# Поколение 491 | Лучшая длина маршрута: 8744.09 км
# Поколение 492 | Лучшая длина маршрута: 8744.09 км
# Поколение 493 | Лучшая длина маршрута: 8744.09 км
# Поколение 494 | Лучшая длина маршрута: 8744.09 км
# Поколение 495 | Лучшая длина маршрута: 8744.09 км
# Поколение 496 | Лучшая длина маршрута: 8744.09 км
# Поколение 497 | Лучшая длина маршрута: 8744.09 км
# Поколение 498 | Лучшая длина маршрута: 8744.09 км
# Поколение 499 | Лучшая длина маршрута: 8744.09 км
# Поколение 500 | Лучшая длина маршрута: 8744.09 км
# Лучший маршрут: [2, 3, 18, 10, 17, 11, 5, 9, 7, 4, 13, 15, 6, 8, 12, 16, 19, 20, 0, 1, 14]
# Общая длина маршрута: 8744.09 км

# %% [markdown]
# ### Визуализация результата

# %%
import matplotlib.cm as cm

plt.figure(figsize=(16, 12))

# Города с тенью для объёма
plt.scatter(
    historic_large_cities["geo_lon"], 
    historic_large_cities["geo_lat"], 
    c="red", s=120, edgecolors='black', linewidth=0.7, alpha=0.9, zorder=5
)

# Цветовой градиент для маршрута (от начала к концу)
route_order = best.chromosome + [best.chromosome[0]]
route_lng = [historic_large_cities.iloc[i]["geo_lon"] for i in route_order]
route_lat = [historic_large_cities.iloc[i]["geo_lat"] for i in route_order]

colors = cm.viridis(np.linspace(0, 1, len(route_order)-1))
for i in range(len(route_order)-1):
    plt.plot(
        route_lng[i:i+2], route_lat[i:i+2], 
        color=colors[i], linewidth=3, alpha=0.8, zorder=4
    )

# Номера и подписи городов с фоном
for i, city_idx in enumerate(best.chromosome):
    city = historic_large_cities.iloc[city_idx]

    plt.text(
        city["geo_lon"], city["geo_lat"], str(i+1),
        fontsize=12, ha="center", va="center",
        bbox=dict(facecolor="white", alpha=0.8, boxstyle="circle"), zorder=6
    )

    plt.text(
        city["geo_lon"] + 0.6, city["geo_lat"] + 0.3,
        f'{city["address"]}',
        fontsize=10, ha="left", va="center",
        bbox=dict(facecolor="white", alpha=0.6, boxstyle="round,pad=0.3"), zorder=6
    )

# Настройки графика
plt.title(
    "Оптимальный маршрут коммивояжера через города России\n"
    f"Общая длина маршрута: {best._total_distance:.2f} км",
    fontsize=16, pad=20
)
plt.xlabel("Долгота", fontsize=14)
plt.ylabel("Широта", fontsize=14)
plt.grid(alpha=0.25)
plt.tight_layout()

# Легенда с кастомными маркерами
from matplotlib.lines import Line2D
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Города', markerfacecolor='red', markersize=12, markeredgecolor='black'),
    Line2D([0], [0], color=cm.viridis(0.6), lw=3, label='Маршрут')
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=12)

plt.show()

# %% [markdown]
# ### Визуализация результата на карте

# %%
import folium


# Создаем базовую карту центрированную на Европе
m = folium.Map(location=[50.0, 15.0], zoom_start=4, tiles="CartoDB positron")

# Добавляем маркеры для каждого города
for idx, row in historic_large_cities.iterrows():
    pop_text: str = f"{row["address"]}, {row["region"]}<br>Население: {int(row["population"]):,}"
    folium.CircleMarker(
        location=[row["geo_lat"], row["geo_lon"]],
        radius=row["population"]/3000000,
        popup=pop_text,
        color="#3186cc",
        fill=True,
        fill_color="#3186cc"
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_492be6f218b3233e77ac2192da6ed789 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_492be6f218b3233e77ac2192da6ed789&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_492be6f218b3233e77ac2192da6ed789 = L.map(
#                 &quot;map_492be6f218b3233e77ac2192da6ed789&quot;,
#                 {
#                     center: [50.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e4a145a58ec3389afaeea165e848ae5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e4a145a58ec3389afaeea165e848ae5.addTo(map_492be6f218b3233e77ac2192da6ed789);
#
#
#             var circle_marker_b4c01f03575b46a816ebe1f12ec322bb = L.circleMarker(
#                 [55.7540471, 37.620405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.83811, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_492be6f218b3233e77ac2192da6ed789);
#
#
#         var popup_187decc57e0750dfd112be91d6b5ad7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_795e05fda136dc037eb05b00f160f65a = $(`&lt;div id=&quot;html_795e05fda136dc037eb05b00f160f65a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;г Москва, Москва&lt;br&gt;Население: 11,514,330&lt;/div&gt;`)[0];
#                 popup_187decc57e0750dfd112be91d6b5ad7a.setContent(html_795e05fda136dc037eb05b00f160f65a);
#
#
#
#         circle_marker_b4c01f03575b46a816ebe1f12ec322bb.bindPopup(popup_187decc57e0750dfd112be91d6b5ad7a)
#         ;
#
#
#
#
#             var circle_marker_aaf8cd596946b4e08dd2373b4f5bb2b3 = L.circleMarker(
#                 [59.9391313, 30.3159004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.6162473333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_492be6f218b3233e77ac2192da6ed789);
#
#
#         var popup_9d692e77b32e2d662f29305955c269ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba5a5a900795df52fbfba12bad53fc9d = $(`&lt;div id=&quot;html_ba5a5a900795df52fbfba12bad53fc9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;г Санкт-Петербург, Санкт-Петербург&lt;br&gt;Население: 4,848,742&lt;/div&gt;`)[0];
#                 popup_9d692e77b32e2d662f29305955c269ca.setContent(html_ba5a5a900795df52fbfba12bad53fc9d);
#
#
#
#         circle_marker_aaf8cd596946b4e08dd2373b4f5bb2b3.bindPopup(popup_9d692e77b32e2d662f29305955c269ca)
#         ;
#
#
#
#
#             var circle_marker_c5e6e08b33c406a840cba872a5ed9c11 = L.circleMarker(
#                 [56.3240627, 44.0053913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.41687166666666664, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_492be6f218b3233e77ac2192da6ed789);
#
#
#         var popup_1f113bb7ff1f824348705e7e9b163de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fc40946e94b9f3b7506212837f8b037 = $(`&lt;div id=&quot;html_6fc40946e94b9f3b7506212837f8b037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;г Нижний Новгород, Нижегородская&lt;br&gt;Население: 1,250,615&lt;/div&gt;`)[0];
#                 popup_1f113bb7ff1f82434870

# %%
import folium
from branca.colormap import linear


# Создаем карту центрированную на средних координатах городов
avg_lat = historic_large_cities["geo_lat"].mean()
avg_lng = historic_large_cities["geo_lon"].mean()
m = folium.Map(location=[avg_lat, avg_lng], zoom_start=5, tiles="CartoDB positron")

# Создаем цветовую шкалу для маршрута
colormap = linear.PuRd_09.scale(0, len(best.chromosome)-1)

# Добавляем маркеры для каждого города
for idx, row in historic_large_cities.iterrows():
    folium.CircleMarker(
        location=[row["geo_lat"], row["geo_lon"]],
        radius=5,
        popup=f"{row["address"]}, {row["region"]}",
        color="#3186cc",
        fill=True,
        fill_color="#3186cc"
    ).add_to(m)

# Добавляем линии маршрута
route_coords = []
for i, city_idx in enumerate(best.chromosome):
    city = historic_large_cities.iloc[city_idx]
    route_coords.append([city["geo_lat"], city["geo_lon"]])
    
    # Добавляем номер посещения
    folium.Marker(
        location=[city["geo_lat"], city["geo_lon"]],
        icon=folium.DivIcon(
            icon_size=(30,30),
            icon_anchor=(15,15),
            html=f"<div style='font-size: 10pt; color: white; background: #3186cc; border-radius: 50%; width: 20px; height: 20px; display: flex; align-items: center; justify-content: center;'>{i+1}</div>"
        )
    ).add_to(m)

# Замыкаем маршрут (возвращаемся в начальный город)
route_coords.append(route_coords[0])

# Добавляем линию маршрута с цветовой градиентной шкалой
for i in range(len(route_coords)-1):
    folium.PolyLine(
        locations=[route_coords[i], route_coords[i+1]],
        color=colormap(i),
        weight=3,
        opacity=0.8
    ).add_to(m)

# Добавляем легенду с цветовой шкалой
colormap.caption = f"Оптимальный маршрут коммивояжера через городов Европы"
colormap.add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23f52c8d138e9014fb677c84cde87dcf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23f52c8d138e9014fb677c84cde87dcf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23f52c8d138e9014fb677c84cde87dcf = L.map(
#                 &quot;map_23f52c8d138e9014fb677c84cde87dcf&quot;,
#                 {
#                     center: [53.3071178047619, 44.682697009523814],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_783c6488d616927fb058843ccef3b8ca = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_783c6488d616927fb058843ccef3b8ca.addTo(map_23f52c8d138e9014fb677c84cde87dcf);
#
#
#             var circle_marker_d3fc284ed09bf7558ebd5e50f2481b12 = L.circleMarker(
#                 [55.7540471, 37.620405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_23f52c8d138e9014fb677c84cde87dcf);
#
#
#         var popup_2883164c2a004c7843bea4624c017c71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec6086a3c08d4c7f4386b3c71a6dcfdd = $(`&lt;div id=&quot;html_ec6086a3c08d4c7f4386b3c71a6dcfdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;г Москва, Москва&lt;/div&gt;`)[0];
#                 popup_2883164c2a004c7843bea4624c017c71.setContent(html_ec6086a3c08d4c7f4386b3c71a6dcfdd);
#
#
#
#         circle_marker_d3fc284ed09bf7558ebd5e50f2481b12.bindPopup(popup_2883164c2a004c7843bea4624c017c71)
#         ;
#
#
#
#
#             var circle_marker_406168a1a5f84db87ec4204221a0f303 = L.circleMarker(
#                 [59.9391313, 30.3159004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_23f52c8d138e9014fb677c84cde87dcf);
#
#
#         var popup_168229132d36ddc075d2190a297df1d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddf9cf4e9b4fcf5e52dbc650eff9a118 = $(`&lt;div id=&quot;html_ddf9cf4e9b4fcf5e52dbc650eff9a118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;г Санкт-Петербург, Санкт-Петербург&lt;/div&gt;`)[0];
#                 popup_168229132d36ddc075d2190a297df1d1.setContent(html_ddf9cf4e9b4fcf5e52dbc650eff9a118);
#
#
#
#         circle_marker_406168a1a5f84db87ec4204221a0f303.bindPopup(popup_168229132d36ddc075d2190a297df1d1)
#         ;
#
#
#
#
#             var circle_marker_66e5ea04e432dd1f3b63f7b0d8debac5 = L.circleMarker(
#                 [56.3240627, 44.0053913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_23f52c8d138e9014fb677c84cde87dcf);
#
#
#         var popup_701e04c25fe4b8a7d727eba1cacb629b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5868be7e02a6b35cc714e0e3e66fbbf = $(`&lt;div id=&quot;html_d5868be7e02a6b35cc714e0e3e66fbbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;г Нижний Новгород, Нижегородская&lt;/div&gt;`)[0];
#                 popup_701e04c25fe4b8a7d7

# %% [markdown]
# ### Использование библиотеки PyGAD

# %%
import pygad
import numpy as np

def order_crossover(parents: np.ndarray, offspring_size: tuple, ga_instance: pygad.GA) -> np.ndarray:
    offspring = []
    idx = 0
    
    while len(offspring) < offspring_size[0]:
        parent1 = parents[idx % parents.shape[0], :].copy()
        parent2 = parents[(idx + 1) % parents.shape[0], :].copy()
        
        size = parent1.shape[0]
        start, end = sorted(np.random.choice(range(size), 2, replace=False))
        
        child1 = -1 * np.ones(size, dtype=int)
        child1[start:end] = parent1[start:end]
        
        ptr = end
        for gene in np.concatenate([parent2[end:], parent2[:end]]):
            if gene not in child1[start:end]:
                if ptr >= size:
                    ptr = 0
                child1[ptr] = gene
                ptr += 1
        
        offspring.append(child1)
        idx += 1
    
    return np.array(offspring)


def swap_mutation(offspring: np.ndarray, ga_instance: pygad.GA) -> np.ndarray:
    for chromosome_idx in range(offspring.shape[0]):
        if np.random.random() < ga_instance.mutation_probability:
            idx1, idx2 = np.random.choice(offspring.shape[1], 2, replace=False)
            offspring[chromosome_idx, idx1], offspring[chromosome_idx, idx2] = \
                offspring[chromosome_idx, idx2], offspring[chromosome_idx, idx1]
    return offspring


def fitness_func(ga_instance: pygad.GA, solution: np.ndarray, solution_idx: int) -> float:
    # Проверка на уникальность генов
    if len(set(solution)) != len(solution):
        return 0.0  # Возвращаем очень плохое значение фитнеса для невалидных решений
    
    total_distance = 0.0
    for i in range(len(solution)):
        j: int = (i + 1) % len(solution)
        city_i = int(solution[i])
        city_j = int(solution[j])
        total_distance += haversine_distance(coords[city_i], coords[city_j])
    
    return 1 / total_distance


# Подготовка данных
coords = historic_large_cities[["geo_lat", "geo_lon"]].values
num_cities: int = len(coords)

ga_instance = pygad.GA(
    num_generations=500,
    num_parents_mating=20,
    fitness_func=fitness_func,
    sol_per_pop=100,
    num_genes=num_cities,
    gene_type=int,
    init_range_low=0,
    init_range_high=num_cities-1,
    crossover_type=order_crossover,
    mutation_type=swap_mutation,
    mutation_probability=0.05,
    suppress_warnings=True,
    allow_duplicate_genes=False,
    gene_space=list(range(num_cities))
)

# Запуск алгоритма
ga_instance.run()

# Получение лучшего решения
best_solution_pygad = ga_instance.best_solution()

# Преобразование результата в наш формат
best_chromosome = [int(gene) for gene in best_solution_pygad[0]]
distance_matrix = np.zeros((num_cities, num_cities))
for i in range(num_cities):
    for j in range(num_cities):
        if i != j:
            distance_matrix[i][j] = haversine_distance(coords[i], coords[j])

tsp_solution = Chromosome(best_chromosome, distance_matrix)

# Вывод результатов
print("\nРезультат работы PyGAD:")
print(f"Fitness: {best_solution_pygad[1]}")
print(tsp_solution)
# Out:
# Результат работы PyGAD:
# Fitness: 0.00013504795457417246
# <__main__.Chromosome object at 0x000002B0A331C740>

# %% [markdown]
# ### Визуализация результата PyGAD

# %%
import matplotlib.cm as cm

plt.figure(figsize=(16, 12))

# Города с тенью для объёма
plt.scatter(
    historic_large_cities["geo_lon"], 
    historic_large_cities["geo_lat"], 
    c="red", s=120, edgecolors='black', linewidth=0.7, alpha=0.9, zorder=5
)

# Цветовой градиент для маршрута (от начала к концу)
route_order = tsp_solution.chromosome + [tsp_solution.chromosome[0]]
route_lng = [historic_large_cities.iloc[i]["geo_lon"] for i in route_order]
route_lat = [historic_large_cities.iloc[i]["geo_lat"] for i in route_order]

colors = cm.viridis(np.linspace(0, 1, len(route_order)-1))
for i in range(len(route_order)-1):
    plt.plot(
        route_lng[i:i+2], route_lat[i:i+2], 
        color=colors[i], linewidth=3, alpha=0.8, zorder=4
    )

# Номера и подписи городов с фоном
for i, city_idx in enumerate(tsp_solution.chromosome):
    city = historic_large_cities.iloc[city_idx]

    plt.text(
        city["geo_lon"], city["geo_lat"], str(i+1),
        fontsize=12, ha="center", va="center",
        bbox=dict(facecolor="white", alpha=0.8, boxstyle="circle"), zorder=6
    )

    plt.text(
        city["geo_lon"] + 0.6, city["geo_lat"] + 0.3,
        f'{city["address"]}',
        fontsize=10, ha="left", va="center",
        bbox=dict(facecolor="white", alpha=0.6, boxstyle="round,pad=0.3"), zorder=6
    )

# Настройки графика
plt.title(
    "Оптимальный маршрут коммивояжера через города России\n"
    f"Общая длина маршрута: {best._total_distance:.2f} км",
    fontsize=16, pad=20
)
plt.xlabel("Долгота", fontsize=14)
plt.ylabel("Широта", fontsize=14)
plt.grid(alpha=0.25)
plt.tight_layout()

# Легенда с кастомными маркерами
from matplotlib.lines import Line2D
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Города', markerfacecolor='red', markersize=12, markeredgecolor='black'),
    Line2D([0], [0], color=cm.viridis(0.6), lw=3, label='Маршрут')
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=12)

plt.show()

# %% [markdown]
# ### Интерактивная визуализация PyGAD на карте мира

# %%
# Создаем карту центрированную на средних координатах городов
avg_lat = historic_large_cities["geo_lat"].mean()
avg_lng = historic_large_cities["geo_lon"].mean()
m = folium.Map(location=[avg_lat, avg_lng], zoom_start=5, tiles="CartoDB positron")

# Создаем цветовую шкалу для маршрута
colormap = linear.PuRd_09.scale(0, len(tsp_solution.chromosome)-1)

# Добавляем маркеры для каждого города
for idx, row in historic_large_cities.iterrows():
    folium.CircleMarker(
        location=[row["geo_lat"], row["geo_lon"]],
        radius=5,
        popup=f"{row["city"]}, {row["country"]}",
        color="#3186cc",
        fill=True,
        fill_color="#3186cc"
    ).add_to(m)

# Добавляем линии маршрута
route_coords = []
for i, city_idx in enumerate(tsp_solution.chromosome):
    city = historic_large_cities.iloc[city_idx]
    route_coords.append([city["geo_lat"], city["geo_lon"]])
    
    # Добавляем номер посещения
    folium.Marker(
        location=[city["geo_lat"], city["geo_lon"]],
        icon=folium.DivIcon(
            icon_size=(30,30),
            icon_anchor=(15,15),
            html=f"<div style='font-size: 10pt; color: white; background: #3186cc; border-radius: 50%; width: 20px; height: 20px; display: flex; align-items: center; justify-content: center;'>{i+1}</div>"
        )
    ).add_to(m)

# Замыкаем маршрут (возвращаемся в начальный город)
route_coords.append(route_coords[0])

# Добавляем линию маршрута с цветовой градиентной шкалой
for i in range(len(route_coords)-1):
    folium.PolyLine(
        locations=[route_coords[i], route_coords[i+1]],
        color=colormap(i),
        weight=3,
        opacity=0.8
    ).add_to(m)

# Добавляем легенду с цветовой шкалой
colormap.caption = f"Оптимальный маршрут коммивояжера через городов России"
colormap.add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e24be9ceed47793372657f3166f63d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e24be9ceed47793372657f3166f63d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e24be9ceed47793372657f3166f63d1 = L.map(
#                 &quot;map_4e24be9ceed47793372657f3166f63d1&quot;,
#                 {
#                     center: [53.3071178047619, 44.682697009523814],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_425c963cef081e8af7070ada2e301b79 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_425c963cef081e8af7070ada2e301b79.addTo(map_4e24be9ceed47793372657f3166f63d1);
#
#
#             var circle_marker_f63e692d0a8c671bc00826804a5e6e00 = L.circleMarker(
#                 [55.7540471, 37.620405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e24be9ceed47793372657f3166f63d1);
#
#
#         var popup_f7522b92e39bf2857d4dcafbb2d524a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31335f2b52d9a9019204e9ca5236e150 = $(`&lt;div id=&quot;html_31335f2b52d9a9019204e9ca5236e150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan, Россия&lt;/div&gt;`)[0];
#                 popup_f7522b92e39bf2857d4dcafbb2d524a0.setContent(html_31335f2b52d9a9019204e9ca5236e150);
#
#
#
#         circle_marker_f63e692d0a8c671bc00826804a5e6e00.bindPopup(popup_f7522b92e39bf2857d4dcafbb2d524a0)
#         ;
#
#
#
#
#             var circle_marker_8d727580d263bc0e0fc91fceedaa25eb = L.circleMarker(
#                 [59.9391313, 30.3159004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e24be9ceed47793372657f3166f63d1);
#
#
#         var popup_628700e0487e8f0724a9d5ef00ce32e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_397c4ba6beb9893ec38d4f1a9536abe3 = $(`&lt;div id=&quot;html_397c4ba6beb9893ec38d4f1a9536abe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan, Россия&lt;/div&gt;`)[0];
#                 popup_628700e0487e8f0724a9d5ef00ce32e2.setContent(html_397c4ba6beb9893ec38d4f1a9536abe3);
#
#
#
#         circle_marker_8d727580d263bc0e0fc91fceedaa25eb.bindPopup(popup_628700e0487e8f0724a9d5ef00ce32e2)
#         ;
#
#
#
#
#             var circle_marker_8981eb09c4ae6f3f230bc3f08769c02c = L.circleMarker(
#                 [56.3240627, 44.0053913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e24be9ceed47793372657f3166f63d1);
#
#
#         var popup_33f004b645cdc959a0df2364815ab933 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_197bf95db9c5fda609d7c279818ed29f = $(`&lt;div id=&quot;html_197bf95db9c5fda609d7c279818ed29f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Нижний Новгород, Россия&lt;/div&gt;`)[0];
#                 popup_33f004b645cdc959a0df2364815ab933.setContent(html_197bf9

# %% [markdown]
# ### Путь в строке GA

# %%
def print_city_route(best_chromosome, city_df):
    """Печатает маршрут обхода городов с направлением.
        best_chromosome: список индексов городов (например, best.chromosome)
        city_df: DataFrame с данными городов (например, historic_large_cities)
    """
    print("Маршрут коммивояжера:\n")
    
    for i in range(len(best_chromosome)):
        city_idx = best_chromosome[i]
        city_name = city_df.iloc[city_idx]["address"]
        print(f"{i + 1}. {city_name}")
        if i < len(best_chromosome) - 1:
            print("↓")
    
    # Возвращение в начальный город
    start_city = city_df.iloc[best_chromosome[0]]["address"]
    print("↓")
    print(f"{len(best_chromosome) + 1}. {start_city} (возвращение в начальный город)")

print_city_route(best.chromosome, historic_large_cities)
# Out:
# Маршрут коммивояжера:
#
# 1. г Нижний Новгород
# ↓
# 2. г Казань
# ↓
# 3. г Пенза
# ↓
# 4. г Саратов
# ↓
# 5. г Астрахань
# ↓
# 6. г Краснодар
# ↓
# 7. г Ростов-на-Дону
# ↓
# 8. г Воронеж
# ↓
# 9. г Волгоград
# ↓
# 10. г Самара
# ↓
# 11. г Ульяновск
# ↓
# 12. г Оренбург
# ↓
# 13. г Уфа
# ↓
# 14. г Пермь
# ↓
# 15. г Ижевск
# ↓
# 16. г Рязань
# ↓
# 17. г Липецк
# ↓
# 18. г Тула
# ↓
# 19. г Москва
# ↓
# 20. г Санкт-Петербург
# ↓
# 21. г Ярославль
# ↓
# 22. г Нижний Новгород (возвращение в начальный город)

# %% [markdown]
# ### Путь в строке PyGad

# %%
print_city_route(tsp_solution.chromosome, historic_large_cities)
# Out:
# Маршрут коммивояжера:
#
# 1. г Самара
# ↓
# 2. г Саратов
# ↓
# 3. г Пенза
# ↓
# 4. г Рязань
# ↓
# 5. г Тула
# ↓
# 6. г Москва
# ↓
# 7. г Санкт-Петербург
# ↓
# 8. г Ярославль
# ↓
# 9. г Нижний Новгород
# ↓
# 10. г Липецк
# ↓
# 11. г Воронеж
# ↓
# 12. г Ростов-на-Дону
# ↓
# 13. г Краснодар
# ↓
# 14. г Волгоград
# ↓
# 15. г Астрахань
# ↓
# 16. г Оренбург
# ↓
# 17. г Уфа
# ↓
# 18. г Пермь
# ↓
# 19. г Ижевск
# ↓
# 20. г Казань
# ↓
# 21. г Ульяновск
# ↓
# 22. г Самара (возвращение в начальный город)

# %%
plt.figure(figsize=(10, 5))
plt.plot(fitness_history, label="Длина лучшего маршрута")
plt.xlabel("Поколение")
plt.ylabel("Длина маршрута (км)")
plt.title("Динамика длины маршрута в генетическом алгоритме")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
